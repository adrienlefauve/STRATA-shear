# %%
# !python export_netcdf_slices_from_binary_3D.py  \
  --case R8P7 \
  --planes yz \
  --idx_yz 11520 \
  --vars ee chi \
  --nproc 2 \
  --stream \
  --overwrite
# Out:
# [adrienExportSlicesNetCDFParallelVarByVar] starting
# [export_slices] case=R8P7 tStamp=42.000090
# [export_slices] outdir=/lustre/orion/cfd135/proj-shared/Hsst/R8P7/001_Final/2D_slices
# [export_slices] stride=(1, 1, 1) planes=['yz'] vars=['ee', 'chi']
# [export_slices] idx lists: xy(iz)=[2880] xz(iy)=[5760] yz(ix)=[11520]
# [export_slices] nproc=2
# [export_slices] 2 var-by-var tasks
# [adrienExportSlicesNetCDFParallelVarByVar] starting
# [adrienExportSlicesNetCDFParallelVarByVar] starting
# [export] R8P7 var=ee plane=yz x11520 stride=(1, 1, 1)
#
# [save_raw_plane_netcdf] writing /lustre/orion/cfd135/proj-shared/Hsst/R8P7/001_Final/2D_slices/R8P7_yz_x11520_st1x1_ee.nc
#   plane=yz ix=11520 stride=(1, 1, 1)
#   dims: y=11520, z=5760
# [export] R8P7 var=chi plane=yz x11520 stride=(1, 1, 1)
#
# [save_raw_plane_netcdf] writing /lustre/orion/cfd135/proj-shared/Hsst/R8P7/001_Final/2D_slices/R8P7_yz_x11520_st1x1_chi.nc
#   plane=yz ix=11520 stride=(1, 1, 1)
#   dims: y=11520, z=5760
